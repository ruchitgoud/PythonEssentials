# %% [markdown]
# **Exceptions, HOFs & Classes/Objects**

# %%
class InsufficientFundsError(Exception):
    pass


class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def withdraw(self, amount):
        if amount > self.balance:
            raise InsufficientFundsError("Insufficient balance!")

        self.balance -= amount
        print(f"Withdrawn: ₹{amount}")
        print(f"Remaining Balance: ₹{self.balance}")


account = BankAccount(5000)

try:
    amount = float(input("Enter withdrawal amount: "))
    account.withdraw(amount)

except InsufficientFundsError as e:
    print(f"Error: {e}")

finally:
    print("Transaction completed.")
# Out:
# Enter withdrawal amount: 4000
# Withdrawn: ₹4000.0
# Remaining Balance: ₹1000.0
# Transaction completed.

# %%
prices = [500, 1000, 1500, 2000, 2500]

def apply_discount(price):
    return price * 0.90


discounted_prices = list(map(apply_discount, prices))

print("Original Prices:", prices)
print("After 10% Discount:", discounted_prices)
# Out:
# Original Prices: [500, 1000, 1500, 2000, 2500]
# After 10% Discount: [450.0, 900.0, 1350.0, 1800.0, 2250.0]
